# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Annotation.xlsx')
data.head(10)
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
# 5   5           50      Female  5_left.jpg  5_right.jpg
# 6   6           60        Male  6_left.jpg  6_right.jpg
# 7   7           60      Female  7_left.jpg  7_right.jpg
# 8   8           59        Male  8_left.jpg  8_right.jpg
# 9   9           54        Male  9_left.jpg  9_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
# ...

# %%
myopia= ['wet age-related macular degeneration','dry age-related macular degeneration']


data[(data['Left-Diagnostic Keywords'].isin(myopia)) & (data['Right-Diagnostic Keywords'].isin(myopia))]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 48      48           69      Female    48_left.jpg    48_right.jpg
# 53      53           65      Female    53_left.jpg    53_right.jpg
# 55      55           62        Male    55_left.jpg    55_right.jpg
# 102    102           73      Female   102_left.jpg   102_right.jpg
# 126    126           66        Male   126_left.jpg   126_right.jpg
# ...    ...          ...         ...            ...             ...
# 1509  1885           66        Male  1885_left.jpg  1885_right.jpg
# 1510  1886           74      Female  1886_left.jpg  1886_right.jpg
# 1511  1889           45        Male  1889_left.jpg  1889_right.jpg
# 1514  1892           69      Female  1892_left.jpg  1892_right.jpg
# 1515  1893           67      Female  1893_left.jpg  1893_right.jpg
#
#                   Left-Diagnostic Keywords  \
# 48    dry age-related macular degeneration
# 53    wet age-related macular degeneration
# ...

# %%
data[data.A==1]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 43      43           35        Male    43_left.jpg    43_right.jpg
# 48      48           69      Female    48_left.jpg    48_right.jpg
# 53      53           65      Female    53_left.jpg    53_right.jpg
# 55      55           62        Male    55_left.jpg    55_right.jpg
# 71      71           56      Female    71_left.jpg    71_right.jpg
# ...    ...          ...         ...            ...             ...
# 1556  2078           42      Female  2078_left.jpg  2078_right.jpg
# 2866  3979           54        Male  3979_left.jpg  3979_right.jpg
# 2943  4068           58        Male  4068_left.jpg  4068_right.jpg
# 3187  4330           57      Female  4330_left.jpg  4330_right.jpg
# 3499  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 43                 wet age-related macular degeneration
# ...

# %%
data[(data['Left-Diagnostic Keywords']=='normal fundus') & (data['Right-Diagnostic Keywords']=='normal fundus')]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 8        8           59        Male     8_left.jpg     8_right.jpg
# 84      84           51      Female    84_left.jpg    84_right.jpg
# 191    191           51      Female   191_left.jpg   191_right.jpg
# 393    394           63        Male   394_left.jpg   394_right.jpg
# ...    ...          ...         ...            ...             ...
# 2824  3448           63        Male  3448_left.jpg  3448_right.jpg
# 2825  3450           59        Male  3450_left.jpg  3450_right.jpg
# 2826  3485           70        Male  3485_left.jpg  3485_right.jpg
# 3399  4571           51        Male  4571_left.jpg  4571_right.jpg
# 3464  4637           45        Male  4637_left.jpg  4637_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 1               normal fundus             normal fundus  1  0  0  0  0  0  0
# ...

# %%
data[data['Left-Diagnostic Keywords']=='normal fundus']
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 3        3           66        Male     3_left.jpg     3_right.jpg
# 8        8           59        Male     8_left.jpg     8_right.jpg
# 9        9           54        Male     9_left.jpg     9_right.jpg
# 14      14           55        Male    14_left.jpg    14_right.jpg
# ...    ...          ...         ...            ...             ...
# 3464  4637           45        Male  4637_left.jpg  4637_right.jpg
# 3466  4639           60      Female  4639_left.jpg  4639_right.jpg
# 3468  4641           56        Male  4641_left.jpg  4641_right.jpg
# 3486  4672           65        Male  4672_left.jpg  4672_right.jpg
# 3494  4683           58        Male  4683_left.jpg  4683_right.jpg
#
#      Left-Diagnostic Keywords          Right-Diagnostic Keywords  N  D  G  C  \
# 1               normal fundus                      normal fundus  1  0  0  0
# ...

# %%
1433+1383+1001
# Out:
# 3817

# %%
data[data['Left-Diagnostic Keywords']=='retinochoroidal coloboma']
# Out:
#       ID  Patient Age Patient Sex   Left-Fundus   Right-Fundus  \
# 76    76           70        Male   76_left.jpg   76_right.jpg
# 655  656           72        Male  656_left.jpg  656_right.jpg
# 849  851           71        Male  851_left.jpg  851_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 76   retinochoroidal coloboma  retinochoroidal coloboma  0  0  0  0  0  0  0
# 655  retinochoroidal coloboma  retinochoroidal coloboma  0  0  0  0  0  0  0
# 849  retinochoroidal coloboma  retinochoroidal coloboma  0  0  0  0  0  0  0
#
#      O
# 76   1
# 655  1
# 849  1

# %%
data.head()
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# ...

# %%
Normal_Fundas = ['normal fundas',
                 'normal fundus，lens dust',
                 'normal fundus，normal fundus',
                 'lens dust',
                 'lens dust，lens dust',
                 'lens dust，lens dust，lens dust',
                 'normal fundus，normal fundus',
                 'low image quality']


data[~data['Left-Diagnostic Keywords'].isin(Normal_Fundas)]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        3           66        Male     3_left.jpg     3_right.jpg
# 4        4           53        Male     4_left.jpg     4_right.jpg
# ...    ...          ...         ...            ...             ...
# 3495  4686           63        Male  4686_left.jpg  4686_right.jpg
# 3496  4688           42        Male  4688_left.jpg  4688_right.jpg
# 3497  4689           54        Male  4689_left.jpg  4689_right.jpg
# 3498  4690           57        Male  4690_left.jpg  4690_right.jpg
# 3499  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %%
Normal Fundas (N):-                     'normal fundas',
                                        'normal fundus，lens dust',
                                        'normal fundus，normal fundus',
                                        'lens dust',
                                        'lens dust，lens dust',
                                        'lens dust，lens dust，lens dust',
                                        'normal fundus，normal fundus',
                                        'low image quality'



Diabetic retinopathy (D):-              'diabetic retinopathy',
                                        'proliferative diabetic retinopathy',
                                        'severe nonproliferative retinopathy', 
                                        'severe proliferative diabetic retinopathy',
                                        'moderate non proliferative retinopathy',
                                        'mild nonproliferative retinopathy',
                                        'severe nonproliferative retinopathy'


Glaucoma  (G):-                          'glaucoma',
                                         'suspected glaucoma'

        
Cataract (C):-                          'cataract'
    
    
age-related macular degeneration (A):-  'wet age-related macular degeneration',
                                        'dry age-related macular degeneration',
    
    
hypertensive retinopathy (H):-          'hypertensive retinopathy'
    

myopia (M):-                            'myopia',
                                        'pathological myopia',
                                        'myopia retinopathy',
                                        'myopic maculopathy',

        
Others (O):-     'laser spot', 
                 'drusen',
                 'epiretinal membrane', 
                 'retinal pigmentation',
                 'rhegmatogenous retinal detachment',
                'spotted membranous change',
                'macular epiretinal membrane',
                'myelinated nerve fibers',
                'atrophy',
                'white vessel',
                'chorioretinal atrophy',
                'retinochoroidal coloboma',
                'retinitis pigmentosa',
                'vitreous degeneration',
                'branch retinal vein occlusion', 
                'optic disc edema',

# %%
data[data.O==1]['Left-Diagnostic Keywords'].unique()
# Out:
# array(['laser spot，moderate non proliferative retinopathy',
#        'normal fundus', 'macular epiretinal membrane', 'drusen',
#        'epiretinal membrane', 'retinal pigmentation',
#        'rhegmatogenous retinal detachment',
#        'moderate non proliferative retinopathy，laser spot',
#        'moderate non proliferative retinopathy',
#        'post laser photocoagulation，glaucoma',
#        'lens dust，spotted membranous change',
#        'macular epiretinal membrane，mild nonproliferative retinopathy',
#        'macular hole',
#        'epiretinal membrane，moderate non proliferative retinopathy，laser spot',
#        'moderate non proliferative retinopathy，myelinated nerve fibers',
#        'lens dust，normal fundus',
#        'epiretinal membrane，myelinated nerve fibers',
#        'diabetic retinopathy', 'epiretinal membrane，lens dust', 'atrophy',
#        'laser spot，white vessel，moderate non proliferative retinopathy',
# ...

# %%
data['Left-Diagnostic Keywords'].unique()
# Out:
# array(['cataract', 'normal fundus',
#        'laser spot，moderate non proliferative retinopathy',
#        'macular epiretinal membrane',
#        'moderate non proliferative retinopathy', 'drusen',
#        'epiretinal membrane',
#        'moderate non proliferative retinopathy，hypertensive retinopathy',
#        'retinal pigmentation', 'pathological myopia',
#        'mild nonproliferative retinopathy',
#        'rhegmatogenous retinal detachment',
#        'moderate non proliferative retinopathy，laser spot',
#        'hypertensive retinopathy', 'post laser photocoagulation，glaucoma',
#        'lens dust，spotted membranous change',
#        'macular epiretinal membrane，mild nonproliferative retinopathy',
#        'macular hole',
#        'epiretinal membrane，moderate non proliferative retinopathy，laser spot',
#        'wet age-related macular degeneration',
#        'moderate non proliferative retinopathy，myelinated nerve fibers',
# ...

# %%
data['Left-Diagnostic Keywords'].value_counts()
# Out:
# normal fundus                                          1433
# moderate non proliferative retinopathy                  366
# mild nonproliferative retinopathy                       220
# cataract                                                135
# pathological myopia                                     111
#                                                        ...
# vitreous degeneration，lens dust                           1
# macular epiretinal membrane，laser spot                    1
# macular coloboma                                          1
# image offset                                              1
# white vessel，moderate non proliferative retinopathy       1
# Name: Left-Diagnostic Keywords, Length: 227, dtype: int64

# %%
# set the root path

import os
import pandas as pd
root_dir = os.path.abspath('.')
# set the data dir
data_dir = '../input'

# %%
train = pd.read_excel('Annotation.xlsx')

# %%
train.head()
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# ...
